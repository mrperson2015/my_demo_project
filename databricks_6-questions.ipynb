# %% [markdown]
# # To be proficient in Spark, one must have three fundamental skills:
#
#   1. The ability to **manipulate and understand the data**
#   1. The knowledge on **how to bend the tool to the programmer’s needs**
#   1. The art of finding a **balance among the factors that affect Spark jobs executions**
#
# The following exercises will help to assess the skills above.

# %% [markdown]
# # Databricks File Upload Instructions
# 1. Browse to `Data` in the sidebar
# </br>![databricks_1.png](/files/tables/Databricks/databricks_1.png)
# 1. Select Create Table
# </br>![databricks_2.png](/files/tables/Databricks/databricks_2.png)
# 1. Browse to the files in the git project downloaded `...\my_demo_project\docker_data\zeppelin\files\Databricks`
# </br>![databricks_3.png](/files/tables/Databricks/databricks_3.png)
# 1. Drag 3 folders to the upload section in Databricks
#   1. AdventureWorks
#   1. Databricks
#   1. INFORMATION_SCHEMA
# </br>![databricks_4.png](/files/tables/Databricks/databricks_4.png)
# 1. Once the files are uploaded, you should see something like the following
# </br>![databricks_5.png](/files/tables/Databricks/databricks_5.png)

# %%
display(dbutils.fs.ls("/FileStore/tables"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/AWBuildVersion/</td><td>AWBuildVersion/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Address/</td><td>Address/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/AddressType/</td><td>AddressType/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/AdventureWorks/</td><td>AdventureWorks/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/BillOfMaterials/</td><td>BillOfMaterials/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/BusinessEntity/</td><td>BusinessEntity/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/BusinessEntityAddress/</td><td>BusinessEntityAddress/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/BusinessEntityContact/</td><td>BusinessEntityContact/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/ContactType/</td><td>ContactType/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/CountryRegion/</td><td>CountryRegion/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/CountryRegionCurrency/</td><td>CountryRegionCurrency/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/CreditCard/</td><td>CreditCard/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Culture/</td><td>Culture/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Currency/</td><td>Currency/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/CurrencyRate/</td><td>CurrencyRate/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Customer/</td><td>Customer/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/DatabaseLog/</td><td>DatabaseLog/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Databricks/</td><td>Databricks/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Department/</td><td>Department/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Document/</td><td>Document/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/EmailAddress/</td><td>EmailAddress/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Employee/</td><td>Employee/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/EmployeeDepartmentHistory/</td><td>EmployeeDepartmentHistory/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/EmployeePayHistory/</td><td>EmployeePayHistory/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/INFORMATION_SCHEMA/</td><td>INFORMATION_SCHEMA/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Illustration/</td><td>Illustration/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/JobCandidate/</td><td>JobCandidate/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Location/</td><td>Location/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Password/</td><td>Password/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Person/</td><td>Person/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/PersonCreditCard/</td><td>PersonCreditCard/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/PersonPhone/</td><td>PersonPhone/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/PhoneNumberType/</td><td>PhoneNumberType/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Product/</td><td>Product/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/ProductCategory/</td><td>ProductCategory/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/ProductCostHistory/</td><td>ProductCostHistory/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/ProductDescription/</td><td>ProductDescription/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/ProductDocument/</td><td>ProductDocument/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/ProductInventory/</td><td>ProductInventory/</td><td>0</td> ...

# %% [markdown]
# # The Dataset
# Let’s describe briefly the dataset that we are going to use. The data consists of extract files from the Microsoft Adventure Works OLTP database. Below you will find a cell querying the INFORMATION_SCHEMA data that gives a list of tables and descriptions. If you were able to upload the files as outlined above, the data is available `/FileStore/tables/...` in parquet format. You can also find a database diagram below or at https://i.stack.imgur.com/LMu4W.gif

# %%
DBFS_path = "/FileStore/tables/"

print(f"Update this path if the data path is different {DBFS_path}")
# Out:
# Update this path if the data path is different /FileStore/tables/

# %% [markdown]
# ![database diagram](/files/tables/db_diagram.gif)

# %%
from pyspark.sql.functions import input_file_name
from pyspark.sql import functions as F

df_information_schema = spark \
    .read \
    .parquet("/FileStore/tables/INFORMATION_SCHEMA/TABLES") \
    .select(F.col("TABLE_NAME"),
            F.col("TABLE_COMMENT"),
            F.concat(F.lit(DBFS_path), F.col("TABLE_NAME")).alias("PARQUET_PATH")) \
    .where("TABLE_SCHEMA = 'AdventureWorks2014'") \
    .orderBy(F.col("TABLE_NAME"))

display(df_information_schema)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TABLE_NAME</th><th>TABLE_COMMENT</th><th>PARQUET_PATH</th></tr></thead><tbody><tr><td>AWBuildVersion</td><td>Current version number of the AdventureWorks 2014 sample database. </td><td>/FileStore/tables/AWBuildVersion</td></tr><tr><td>AWBuildVersion</td><td>Current version number of the AdventureWorks 2014 sample database. </td><td>/FileStore/tables/AWBuildVersion</td></tr><tr><td>Address</td><td>Street address information for customers, employees, and vendors.</td><td>/FileStore/tables/Address</td></tr><tr><td>Address</td><td>Street address information for customers, employees, and vendors.</td><td>/FileStore/tables/Address</td></tr><tr><td>AddressType</td><td>Types of addresses stored in the Address table. </td><td>/FileStore/tables/AddressType</td></tr><tr><td>AddressType</td><td>Types of addresses stored in the Address table. </td><td>/FileStore/tables/AddressType</td></tr><tr><td>BillOfMaterials</td><td>Items required to make bicycles and bicycle subassemblies. It identifies the heirarchical relationship between a parent product and its components.</td><td>/FileStore/tables/BillOfMaterials</td></tr><tr><td>BillOfMaterials</td><td>Items required to make bicycles and bicycle subassemblies. It identifies the heirarchical relationship between a parent product and its components.</td><td>/FileStore/tables/BillOfMaterials</td></tr><tr><td>BusinessEntity</td><td>Source of the ID that connects vendors, customers, and employees with address and contact information.</td><td>/FileStore/tables/BusinessEntity</td></tr><tr><td>BusinessEntity</td><td>Source of the ID that connects vendors, customers, and employees with address and contact information.</td><td>/FileStore/tables/BusinessEntity</td></tr><tr><td>BusinessEntityAddress</td><td>Cross-reference table mapping customers, vendors, and employees to their addresses.</td><td>/FileStore/tables/BusinessEntityAddress</td></tr><tr><td>BusinessEntityAddress</td><td>Cross-reference table mapping customers, vendors, and employees to their addresses.</td><td>/FileStore/tables/BusinessEntityAddress</td></tr><tr><td>BusinessEntityContact</td><td>Cross-reference table mapping stores, vendors, and employees to people</td><td>/FileStore/tables/BusinessEntityContact</td></tr><tr><td>BusinessEntityContact</td><td>Cross-reference table mapping stores, vendors, and employees to people</td><td>/FileStore/tables/BusinessEntityContact</td></tr><tr><td>ContactType</td><td>Lookup table containing the types of business entity contacts.</td><td>/FileStore/tables/ContactType</td></tr><tr><td>ContactType</td><td>Lookup table containing the types of business entity contacts.</td><td>/FileStore/tables/ContactType</td></tr><tr><td>CountryRegion</td><td>Lookup table containing the ISO standard codes for countries and regions.</td><td>/FileStore/tables/CountryRegion</td></tr><tr><td>CountryRegion</td><td>Lookup table containing the ISO standard codes for countries and regions.</td><td>/FileStore/tables/CountryRegion</td></tr><tr><td>CountryRegionCurrency</td><td>Cross-reference table mapping ISO currency codes to a country or region.</td><td>/FileStore/tables/CountryRegionCurrency</td></tr><tr><td>CountryRegionCurrency</td><td>Cross-reference table mapping ISO currency codes to a country or region.</td><td>/FileStore/tables/CountryRegionCurrency</td></tr><tr><td>CreditCard</td><td>Customer credit card information.</td><td>/FileStore/tables/CreditCard</td></tr><tr><td>CreditCard</td><td>Customer credit card information.</td><td>/FileStore/tables/CreditCard</td></tr><tr><td>Culture</td><td>Lookup table containing the languages in which some AdventureWorks data is stored.</td><td>/FileStore/tables/Culture</td></tr><tr><td>Culture</td><td>Lookup table containing the languages in which some AdventureWorks data is stored.</td><td>/FileStore/tables/Culture</td></tr><tr><td>Currency</td><td>Lookup table c ...

# %% [markdown]
# Find out how many of the below are found in the data:
#
#   1. Sales
#   1. Products
#   1. Sellers
#   1. How many products have been sold at least once?
#   1. Which product is found in the most sales?

# %%
df_sales_header       = spark.read.parquet(DBFS_path + "SalesOrderHeader")
df_sales_detail       = spark.read.parquet(DBFS_path + "SalesOrderDetail")
df_sales_person       = spark.read.parquet(DBFS_path + "SalesPerson")
df_production_product = spark.read.parquet(DBFS_path + "Product")

# %% [markdown]
# How many distinct products have been sold each day?

# %%
df_sales_header       = spark.read.parquet(DBFS_path + "SalesOrderHeader")
df_sales_detail       = spark.read.parquet(DBFS_path + "SalesOrderDetail")
df_sales_person       = spark.read.parquet(DBFS_path + "SalesPerson")
df_production_product = spark.read.parquet(DBFS_path + "Product")

# %% [markdown]
# What is the average sub total for every order?

# %%
df_sales_header       = spark.read.parquet(DBFS_path + "SalesOrderHeader")
df_sales_detail       = spark.read.parquet(DBFS_path + "SalesOrderDetail")
df_sales_person       = spark.read.parquet(DBFS_path + "SalesPerson")
df_production_product = spark.read.parquet(DBFS_path + "Product")

# %% [markdown]
# For each seller, what is the average % contribution of an order to the seller's daily quota?
#
# ## Example
# If Seller 1 with `SalesQuota=300000.0` has 3 orders:
#
# Order 1: Sub Total 20,565
# Order 2: Sub Total  1,294
# Order 3: Sub Total 32,726
#
# The average % contribution of orders to the seller's quota would be:
#
# Order 1: 20565/300000.0 = 0.068
# Order 2: 1294 /300000.0 = 0.004
# Order 3: 32726/300000.0 = 0.109
#
# Average % Contribution = (0.068 + 0.004 + 0.109)/3 = 0.06033333

# %%
df_sales_header       = spark.read.parquet(DBFS_path + "SalesOrderHeader")
df_sales_detail       = spark.read.parquet(DBFS_path + "SalesOrderDetail")
df_sales_person       = spark.read.parquet(DBFS_path + "SalesPerson")
df_production_product = spark.read.parquet(DBFS_path + "Product")

# %% [markdown]
# Who are the sellers that sell the second most and least number of each product? Who are those for the product with `ProductId = 1`?

# %%
df_sales_header       = spark.read.parquet(DBFS_path + "SalesOrderHeader")
df_sales_detail       = spark.read.parquet(DBFS_path + "SalesOrderDetail")
df_sales_person       = spark.read.parquet(DBFS_path + "SalesPerson")
df_production_product = spark.read.parquet(DBFS_path + "Product")

# %% [markdown]
# Create a new column called "hashed_approval" defined as follows:
#
#   1. if the order_id is even: apply MD5 hashing iteratively to the CreditCardApprovalCode field, once for each '8' present in the text. E.g. if the Credit Card Approval Code is '105041Vi84182', you would apply hashing two times iteratively (only if the order number is even)
#
#   1. if the order_id is odd: apply SHA256 hashing to the CreditCardApprovalCode text
#
# Finally, check if there are any duplicate on the new column

# %%
df_sales_header       = spark.read.parquet(DBFS_path + "SalesOrderHeader")
df_sales_detail       = spark.read.parquet(DBFS_path + "SalesOrderDetail")
df_sales_person       = spark.read.parquet(DBFS_path + "SalesPerson")
df_production_product = spark.read.parquet(DBFS_path + "Product")
